# %% [markdown]
# # 2. Compute Infection Rates
#
# This notebook contains the workflow for the second milestone in the Manning liveProject *Build Network Models for Pandemics.* *Build Network Models for Pandemics* is part of the series *Federated Learning Over Networks for Pandemics*.

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from geopy.distance import geodesic

# %% [markdown]
# ## Read data and create network (copied from milestone 1)

# %%
csvpath = "../../data/" # path to csv file

# %%
df = pd.read_csv(csvpath + "PeopleLocations_p2.csv", delimiter=";") # import data

# %%
G = nx.Graph()

for idx, person in df.iterrows():
    # format the coordinates
    coord = np.array((person["Lat"],person["Lon"]))
    
    # convert and combine the date and time
    date = datetime.strptime(person["Date"], "%d-%m-%Y").date()
    time = datetime.strptime(person["Time"], "%H:%M:%S").time()
    date_time = datetime.combine(date,time)
    
    # convert y and n into integers
    if person["Covid19"]=="y":
        rate = 1
    else:
        rate = 0
    
    # add node and create attributes
    G.add_node(idx)
    G.nodes[idx]["name"] = person["ID"]
    G.nodes[idx]["coords"] = coord
    G.nodes[idx]["timestamp"] = date_time
    G.nodes[idx]["Rate"] = rate

# %%
for i in G.nodes:
    for j in G.nodes:
        if G.nodes[i] != G.nodes[j]:
            distance = geodesic(G.nodes[i]["coords"], G.nodes[j]["coords"]).m # .m gets the distance from coordinates in meters
            if distance < 2:
                G.add_edge(i,j)

# %% [markdown]
# ## Doing the updates for 10 iterations

# %%
niter = 10

for n in range(niter):
    # I need to copy current rates because I will keep overwriting in these loops
    current_rates = np.fromiter(nx.get_node_attributes(G,'Rate').values(), dtype=float)
    for i in G.nodes:
        neighbors = list(G.neighbors(i))
        W_ii = 1 # the W[i,i] before anything subtracted
        W_ij_term = 0 # what will become sum(W[i,j]*Rate[j]) by the end of the inner loop
        for j in neighbors:
            # note that I am skipping non-neighbors altogether because W[i,j] * Rate[j] = 0 anyway
            W_ii -= 1/(max(G.degree(i), G.degree(j))+1) # W[i,i] - 1/(max(d(i),d(j))+1). The sum will accumulate as loop progresses
            W_ij_term += 1/(max(G.degree(i), G.degree(j))+1) * current_rates[j] # W[i,j] * Rate[j]
        G.nodes[i]["Rate"] = W_ii * current_rates[i] + W_ij_term # Eq1

# %% [markdown]
# ## Printing the updated "Rates"

# %%
for i in G.nodes:
    print("Rates for",G.nodes[i]["name"],":",np.round(G.nodes[i]["Rate"],4))
# Out:
# Rates for Person1 : 0.3012
# Rates for Person2 : 0.3011
# Rates for Person3 : 0.3013
# Rates for Person4 : 0.3012
# Rates for Person5 : 0.301
# Rates for Person6 : 0.3016
# Rates for Person7 : 0.301
# Rates for Person8 : 0.3011
# Rates for Person9 : 0.1994
# Rates for Person10 : 0.3011
# Rates for Person11 : 0.3011
# Rates for Person12 : 0.3011
# Rates for Person13 : 0.3013
# Rates for Person14 : 0.3011
# Rates for Person15 : 0.3013
# Rates for Person16 : 0.3011
# Rates for Person17 : 0.3011
# Rates for Person18 : 0.3013
# Rates for Person19 : 0.301
# Rates for Person20 : 0.3019
# Rates for Person21 : 0.3012
# Rates for Person22 : 0.3014
# Rates for Person23 : 0.3014
# Rates for Person24 : 0.3011
# Rates for Person25 : 0.301
# Rates for Person26 : 0.3013
# Rates for Person27 : 0.3011
# Rates for Person28 : 0.3053
# Rates for Person29 : 0.3011
# Rates for Person30 : 0.3011
# Rates for Person31 : 0.3011
# Rates for Person32 : 0.3015
# Rates for Person33 : 0.3013
# Rates for Person34 : 0.3016
# Rates for Person35 : 0.3011
# Rates for Person36 : 0.3013
# Rates for Person37 : 0.3013
# Rates for Person38 : 0.3011
# Rates for Person39 : 0.2985
# Rates for Person40 : 0.3013
# Rates for Person41 : 0.2995
# Rates for Person42 : 0.2989
# Rates for Person43 : 0.301
# Rates for Person44 : 0.2995
# Rates for Person45 : 0.301
# Rates for Person46 : 0.2971
# Rates for Person47 : 0.3011
# Rates for Person48 : 0.3014
# Rates for Person49 : 0.3015
# Rates for Person50 : 0.3011
# Rates for Person51 : 0.3011
# Rates for Person52 : 0.2983
# Rates for Person53 : 0.3015
# Rates for Person54 : 0.3011
# Rates for Person55 : 0.301
# Rates for Person56 : 0.3011
# Rates for Person57 : 0.301
# Rates for Person58 : 0.301
# Rates for Person59 : 0.3011
# Rates for Person60 : 0.3017
# Rates for Person61 : 0.3011
# Rates for Person62 : 0.3011
# Rates for Person63 : 0.2983
# Rates for Person64 : 0.2993
# Rates for Person65 : 0.3014
# Rates for Person66 : 0.3015
# Rates for Person67 : 0.3011
# Rates for Person68 : 0.3013
# Rates for Person69 : 0.3012
# Rates for Person70 : 0.3015
# Rates for Person71 : 0.301
# Rates for Person72 : 0.3013
# Rates for Person73 : 0.3015
# Rates for Person74 : 0.3011
# Rates for Person75 : 0.3013
# Rates for Person76 : 0.3011
# Rates for Person77 : 0.3011
# Rates for Person78 : 0.3011
# Rates for Person79 : 0.3015
# Rates for Person80 : 0.3011
# Rates for Person81 : 0.3013
# Rates for Person82 : 0.3011
# Rates for Person83 : 0.3011
# Rates for Person84 : 0.3012
# Rates for Person85 : 0.3011
# Rates for Person86 : 0.2994
# Rates for Person87 : 0.3011
# Rates for Person88 : 0.301
# Rates for Person89 : 0.3011
# Rates for Person90 : 0.301
# Rates for Person91 : 0.3012
# Rates for Person92 : 0.3011
# Rates for Person93 : 0.3011
# Rates for Person94 : 0.3011
# Rates for Person95 : 0.3011
# Rates for Person96 : 0.3014
# Rates for Person97 : 0.3013
# Rates for Person98 : 0.3011
# Rates for Person99 : 0.3011
# Rates for Person100 : 0.3013
# Rates for Person101 : 0.4014
# Rates for Person102 : 0.4014
# Rates for Person103 : 0.4016
# Rates for Person104 : 0.4015
# Rates for Person105 : 0.4013
# Rates for Person106 : 0.4017
# Rates for Person107 : 0.4013
# Rates for Person108 : 0.4014
# Rates for Person109 : 0.2805
# Rates for Person110 : 0.4014
# Rates for Person111 : 0.4014
# Rates for Person112 : 0.4014
# Rates for Person113 : 0.4015
# Rates for Person114 : 0.4014
# Rates for Person115 : 0.4016
# Rates for Person116 : 0.4014
# Rates for Person117 : 0.4014
# Rates for Person118 : 0.4016
# Rates for Person119 : 0.4013
# Rates for Person120 : 0.4018
# Rates for Person121 : 0.4014
# Rates for Person122 : 0.4016
# Rates for Person123 : 0.4016
# Rates for Person124 : 0.4014
# Rates for Person125 : 0.4013
# Rates for Person126 : 0.4015
# Rates for Person127 : 0.4014
# Rates for Person128 : 0.4004
# Rates for Person129 : 0.4014
# Rates for Person130 : 0.4014
# Rates for Person131 : 0.4014
# Rates for Person132 : 0.4017
# Rates for Person133 : 0.4015
# Rates for Person134 : 0.4017
# Rates for Person135 : 0.4014
# Rates for Person136 : 0.4015
# Rates for Person137 : 0.4016
# Rates for Person138 : 0.4014
# Rates for Person139 : 0.3985
# Rates for Person140 : 0.4016
# Rates for Person141 : 0.3996
# Rates for Person142 : 0.3989
# Rates for Person143 : 0.4013
# Rates for Person144 : 0.3996
# Rates for Person145 : 0.4013
# Rates for Person146 : 0.3968
# Rates for Person147 : 0.4014
# Rates for Person148 : 0.4017
# Rates for Person149 : 0.4017
# Rates for Person150 : 0.4014
# Rates for Person151 : 0.4014
# Rates for Person152 : 0.3983
# Rates for Person153 : 0.4017
# Rates for Person154 : 0.4014
# Rates for Person155 : 0.4013
# Rates for Person156 : 0.4014
# Rates for Person157 : 0.4013
# Rates for Person158 : 0.4013
# Rates for Person159 : 0.4014
# Rates for Person160 : 0.4017
# Rates for Person161 : 0.4014
# Rates for Person162 : 0.4014
# Rates for Person163 : 0.3982
# Rates for Person164 : 0.3994
# Rates for Person165 : 0.4016
# Rates for Person166 : 0.4017
# Rates for Person167 : 0.4014
# Rates for Person168 : 0.4016
# Rates for Person169 : 0.4014
# Rates for Person170 : 0.4017
# Rates for Person171 : 0.4014
# Rates for Person172 : 0.4016
# Rates for Person173 : 0.4017
# Rates for Person174 : 0.4014
# Rates for Person175 : 0.4016
# Rates for Person176 : 0.4014
# Rates for Person177 : 0.4014
# Rates for Person178 : 0.4014
# Rates for Person179 : 0.4017
# Rates for Person180 : 0.4014
# Rates for Person181 : 0.4015
# Rates for Person182 : 0.4014
# Rates for Person183 : 0.4014
# Rates for Person184 : 0.4014
# Rates for Person185 : 0.4014
# Rates for Person186 : 0.3994
# Rates for Person187 : 0.4014
# Rates for Person188 : 0.4013
# Rates for Person189 : 0.4014
# Rates for Person190 : 0.4013
# Rates for Person191 : 0.4014
# Rates for Person192 : 0.4014
# Rates for Person193 : 0.4014
# Rates for Person194 : 0.4014
# Rates for Person195 : 0.4014
# Rates for Person196 : 0.4016
# Rates for Person197 : 0.4015
# Rates for Person198 : 0.4014
# Rates for Person199 : 0.4014
# Rates for Person200 : 0.4015
# Rates for Person201 : 0.6386
# Rates for Person202 : 0.6387
# Rates for Person203 : 0.6385
# Rates for Person204 : 0.6386
# Rates for Person205 : 0.6387
# Rates for Person206 : 0.6384
# Rates for Person207 : 0.6387
# Rates for Person208 : 0.6387
# Rates for Person209 : 0.7547
# Rates for Person210 : 0.6387
# Rates for Person211 : 0.6387
# Rates for Person212 : 0.6387
# Rates for Person213 : 0.6386
# Rates for Person214 : 0.6387
# Rates for Person215 : 0.6385
# Rates for Person216 : 0.6387
# Rates for Person217 : 0.6387
# Rates for Person218 : 0.6385
# Rates for Person219 : 0.6387
# Rates for Person220 : 0.6382
# Rates for Person221 : 0.6386
# Rates for Person222 : 0.6385
# Rates for Person223 : 0.6385
# Rates for Person224 : 0.6387
# Rates for Person225 : 0.6387
# Rates for Person226 : 0.6386
# Rates for Person227 : 0.6387
# Rates for Person228 : 0.6392
# Rates for Person229 : 0.6387
# Rates for Person230 : 0.6387
# Rates for Person231 : 0.6386
# Rates for Person232 : 0.6384
# Rates for Person233 : 0.6385
# Rates for Person234 : 0.6383
# Rates for Person235 : 0.6387
# Rates for Person236 : 0.6385
# Rates for Person237 : 0.6385
# Rates for Person238 : 0.6387
# Rates for Person239 : 0.6415
# Rates for Person240 : 0.6385
# Rates for Person241 : 0.6404
# Rates for Person242 : 0.641
# Rates for Person243 : 0.6387
# Rates for Person244 : 0.6404
# Rates for Person245 : 0.6387
# Rates for Person246 : 0.6428
# Rates for Person247 : 0.6386
# Rates for Person248 : 0.6384
# Rates for Person249 : 0.6384
# Rates for Person250 : 0.6387
# Rates for Person251 : 0.6387
# Rates for Person252 : 0.6416
# Rates for Person253 : 0.6384
# Rates for Person254 : 0.6386
# Rates for Person255 : 0.6387
# Rates for Person256 : 0.6387
# Rates for Person257 : 0.6387
# Rates for Person258 : 0.6387
# Rates for Person259 : 0.6387
# Rates for Person260 : 0.6383
# Rates for Person261 : 0.6387
# Rates for Person262 : 0.6387
# Rates for Person263 : 0.6417
# Rates for Person264 : 0.6406
# Rates for Person265 : 0.6385
# Rates for Person266 : 0.6384
# Rates for Person267 : 0.6387
# Rates for Person268 : 0.6385
# Rates for Person269 : 0.6386
# Rates for Person270 : 0.6384
# Rates for Person271 : 0.6387
# Rates for Person272 : 0.6385
# Rates for Person273 : 0.6384
# Rates for Person274 : 0.6387
# Rates for Person275 : 0.6385
# Rates for Person276 : 0.6387
# Rates for Person277 : 0.6387
# Rates for Person278 : 0.6387
# Rates for Person279 : 0.6384
# Rates for Person280 : 0.6387
# Rates for Person281 : 0.6385
# Rates for Person282 : 0.6387
# Rates for Person283 : 0.6387
# Rates for Person284 : 0.6386
# Rates for Person285 : 0.6387
# Rates for Person286 : 0.6406
# Rates for Person287 : 0.6387
# Rates for Person288 : 0.6387
# Rates for Person289 : 0.6387
# Rates for Person290 : 0.6387
# Rates for Person291 : 0.6386
# Rates for Person292 : 0.6387
# Rates for Person293 : 0.6387
# Rates for Person294 : 0.6387
# Rates for Person295 : 0.6387
# Rates for Person296 : 0.6385
# Rates for Person297 : 0.6385
# Rates for Person298 : 0.6387
# Rates for Person299 : 0.6386
# Rates for Person300 : 0.6385
